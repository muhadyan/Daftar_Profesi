# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Soal 1

# %%
df = pd.read_csv('profesi.csv', delimiter='|')
df1 = df.groupby(['occupation']).count()
print(df1.index.size)
print(df1.index.tolist())
# Out:
# 21
# ['administrator', 'artist', 'doctor', 'educator', 'engineer', 'entertainment', 'executive', 'healthcare', 'homemaker', 'lawyer', 'librarian', 'marketing', 'none', 'other', 'programmer', 'retired', 'salesman', 'scientist', 'student', 'technician', 'writer']

# %% [markdown]
# # Soal 2

# %%
df.pivot_table(
    index=['occupation', 'gender'],
    values=['age'],
    aggfunc={'age': [np.min, np.max, np.mean]}).rename(columns={'amax': 'max_usia', 'amin':'min_usia', 'mean': 'rerata_usia'})
# Out:
#                           age
#                      max_usia min_usia rerata_usia
# occupation    gender
# administrator F          62.0     22.0   40.638889
#               M          70.0     21.0   37.162791
# artist        F          48.0     19.0   30.307692
#               M          45.0     20.0   32.333333
# doctor        M          64.0     28.0   43.571429
# educator      F          51.0     23.0   39.115385
#               M          63.0     25.0   43.101449
# engineer      F          36.0     23.0   29.500000
#               M          70.0     22.0   36.600000
# entertainment F          38.0     24.0   31.000000
#               M          50.0     15.0   29.000000
# executive     F          49.0     39.0   44.000000
#               M          69.0     22.0   38.172414
# healthcare    F          53.0     22.0   39.818182
#               M          62.0     28.0   45.400000
# homemaker     F          50.0     20.0   34.166667
# ...
